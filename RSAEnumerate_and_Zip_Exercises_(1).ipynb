# %% [markdown]
# In this project, we'll build a complete album tracklist from a couple of plain Python lists, growing it one step at a time with `enumerate` and `zip`.
#
# Here's what we're building toward:
#
# ```
# Main album
# 1. Daylight (3:12)
# 2. Coastline (4:05)
# 3. Paper Planes (2:58)
# 4. Open Road (3:47)
# Bonus tracks
# 5. Reprise (2:40)
# 6. Hidden Gem (3:30)
# 7. Encore (4:15)
# ```
#
# Each part adds one piece, picking up the code right where the last part left off.

# %% [markdown]
# # Part 1
# Print the song titles in `titles` as a numbered list, with the count starting at 1.
#
# **Sample output**
# ```
# 1. Daylight
# 2. Coastline
# 3. Paper Planes
# 4. Open Road
# ```

# %%
titles = ["Daylight", "Coastline", "Paper Planes", "Open Road"]

# TODO: print the titles as a numbered list, starting the count at 1
titles = ["Daylight", "Coastline", "Paper Planes", "Open Road"]

for number, title in enumerate(titles, start=1):
    print(f"{number}. {title}")
# Out:
# 1. Daylight
# 2. Coastline
# 3. Paper Planes
# 4. Open Road

# %% [markdown]
# # Part 2
# Now bring in a second list, `durations`, lined up with the titles, so each line also shows the song's length. Keep the numbering.
#
# **Sample output**
# ```
# 1. Daylight (3:12)
# 2. Coastline (4:05)
# 3. Paper Planes (2:58)
# 4. Open Road (3:47)
# ```

# %%
titles = ["Daylight", "Coastline", "Paper Planes", "Open Road"]
durations = ["3:12", "4:05", "2:58", "3:47"]

for number, title in enumerate(titles, start=1):
    print(f"{number}. {title}")

# TODO: pair in each song's duration with zip, so every line also shows its length
titles = ["Daylight", "Coastline", "Paper Planes", "Open Road"]
durations = ["3:12", "4:05", "2:58", "3:47"]

for number, (title, duration) in enumerate(zip(titles, durations), start=1):
    print(f"{number}. {title} ({duration})")
# Out:
# 1. Daylight
# 2. Coastline
# 3. Paper Planes
# 4. Open Road
# 1. Daylight (3:12)
# 2. Coastline (4:05)
# 3. Paper Planes (2:58)
# 4. Open Road (3:47)

# %% [markdown]
# # Part 3
# Time for the deluxe edition: add three bonus tracks (`bonus_titles`, with their `bonus_durations`) to the end, numbered so they continue the tracklist (5, 6, 7) instead of restarting at 1. Print a heading above each section — `Main album` and `Bonus tracks` — so the two are clearly separated.
#
# **Sample output**
# ```
# Main album
# 1. Daylight (3:12)
# 2. Coastline (4:05)
# 3. Paper Planes (2:58)
# 4. Open Road (3:47)
# Bonus tracks
# 5. Reprise (2:40)
# 6. Hidden Gem (3:30)
# 7. Encore (4:15)
# ```

# %%
titles = ["Daylight", "Coastline", "Paper Planes", "Open Road"]
durations = ["3:12", "4:05", "2:58", "3:47"]
bonus_titles = ["Reprise", "Hidden Gem", "Encore"]
bonus_durations = ["2:40", "3:30", "4:15"]

for number, (title, duration) in enumerate(zip(titles, durations), start=1):
    print(f"{number}. {title} ({duration})")

# TODO: print a "Main album" heading before the loop above, then add the three bonus
# titles in a second loop, numbered to continue at 5, 6, 7, under a "Bonus tracks" heading
titles = ["Daylight", "Coastline", "Paper Planes", "Open Road"]
durations = ["3:12", "4:05", "2:58", "3:47"]
bonus_titles = ["Reprise", "Hidden Gem", "Encore"]
bonus_durations = ["2:40", "3:30", "4:15"]

print("Main album")

for number, (title, duration) in enumerate(zip(titles, durations), start=1):
    print(f"{number}. {title} ({duration})")

print("Bonus tracks")

for number, (title, duration) in enumerate(zip(bonus_titles, bonus_durations), start=5):
    print(f"{number}. {title} ({duration})")
# Out:
# 1. Daylight (3:12)
# 2. Coastline (4:05)
# 3. Paper Planes (2:58)
# 4. Open Road (3:47)
# Main album
# 1. Daylight (3:12)
# 2. Coastline (4:05)
# 3. Paper Planes (2:58)
# 4. Open Road (3:47)
# Bonus tracks
# 5. Reprise (2:40)
# 6. Hidden Gem (3:30)
# 7. Encore (4:15)
